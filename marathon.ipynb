# %%
import pandas as pd

# %%
df = pd.read_csv('Riyadh Marathon Results.csv')

# %%
df
# Out:
#       Unnamed: 0       Rank Gender Rank                                  Name  \
# 0              0  46 / 2285     1 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 1              1  53 / 2285     2 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 2              2  55 / 2285     3 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 3              3  88 / 2285     4 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 4              4  93 / 2285     5 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# ...          ...        ...         ...                                   ...
# 6392           1      5 / 6       2 / 3  cde359f8-5d73-4426-8ba6-cf021cfddbfc
# 6393           2      6 / 6       3 / 3  cde359f8-5d73-4426-8ba6-cf021cfddbfc
# 6394           0      1 / 6       1 / 3  7aa1ce03-6d9c-4b53-93a9-d01b1bae7334
# 6395           1      2 / 6       2 / 3  7aa1ce03-6d9c-4b53-93a9-d01b1bae7334
# 6396           2      3 / 6       3 / 3  7aa1ce03-6d9c-4b53-93a9-d01b1bae7334
#
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0       Rank Gender Rank                                  Name  \
# 0           0  46 / 2285     1 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 1           1  53 / 2285     2 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 2           2  55 / 2285     3 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
#
#    Gender  Category         Nationality      Gun Time     Chip Time  \
# 0  Female  10KM RUN  [img:flags/SA.gif]  00:42:59.556  00:42:57.505
# 1  Female  10KM RUN  [img:flags/CZ.gif]  00:43:28.175  00:43:24.774
# 2  Female  10KM RUN  [img:flags/SA.gif]  00:44:00.251  00:43:56.317
#
#         Speed         Pace Distance
# 0  13.9 Km/Hr  4:17 min/km    10 KM
# 1  13.8 Km/Hr  4:20 min/km    10 KM
# 2  13.6 Km/Hr  4:23 min/km    10 KM

# %%
df.shape
# Out:
# (6397, 12)

# %%
df.describe()
# Out:
#         Unnamed: 0
# count  6397.000000
# mean    537.356886
# std     381.548171
# min       0.000000
# 25%     213.000000
# 50%     477.000000
# 75%     797.000000
# max    1578.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6397 entries, 0 to 6396
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   6397 non-null   int64
#  1   Rank         6397 non-null   object
#  2   Gender Rank  6397 non-null   object
#  3   Name         6397 non-null   object
#  4   Gender       6397 non-null   object
#  5   Category     6397 non-null   object
#  6   Nationality  6085 non-null   object
#  7   Gun Time     6397 non-null   object
#  8   Chip Time    6227 non-null   object
#  9   Speed        6227 non-null   object
#  10  Pace         6227 non-null   object
#  11  Distance     6397 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 599.8+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df
# Out:
#            Rank Gender Rank                                  Name  Gender  \
# 0     46 / 2285     1 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80  Female
# 1     53 / 2285     2 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80  Female
# 2     55 / 2285     3 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80  Female
# 3     88 / 2285     4 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80  Female
# 4     93 / 2285     5 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80  Female
# ...         ...         ...                                   ...     ...
# 6392      5 / 6       2 / 3  cde359f8-5d73-4426-8ba6-cf021cfddbfc  Female
# 6393      6 / 6       3 / 3  cde359f8-5d73-4426-8ba6-cf021cfddbfc  Female
# 6394      1 / 6       1 / 3  7aa1ce03-6d9c-4b53-93a9-d01b1bae7334    Male
# 6395      2 / 6       2 / 3  7aa1ce03-6d9c-4b53-93a9-d01b1bae7334    Male
# 6396      3 / 6       3 / 3  7aa1ce03-6d9c-4b53-93a9-d01b1bae7334    Male
#
#                  Category         Nationality      Gun Time     Chip Time  \
# ...

# %%
df[['Category','Gender']].value_counts()
# Out:
# Category             Gender
# 10KM RUN             Male      1579
# 4KM FUN RUN          Male      1202
#                      Female    1069
# HALF MARATHON        Male       938
# 10KM RUN             Female     795
# MARATHON             Male       478
# HALF MARATHON        Female     233
# MARATHON             Female      75
# MARATHON ELITE       Male        13
#                      Female       9
# HALF MARATHON ELITE  Female       3
#                      Male         3
# Name: count, dtype: int64

# %%
def clean_rank(x):
    return x.split()[0]

# %%
df['Rank'] = df['Rank'].apply(clean_rank)

# %%
df['Gender Rank'] = df['Gender Rank'].apply(clean_rank)

# %%
df.head()
# Out:
#   Rank Gender Rank                                  Name  Gender  Category  \
# 0   46           1  6b848725-e44d-42d8-a278-ae67faa9cb80  Female  10KM RUN
# 1   53           2  6b848725-e44d-42d8-a278-ae67faa9cb80  Female  10KM RUN
# 2   55           3  6b848725-e44d-42d8-a278-ae67faa9cb80  Female  10KM RUN
# 3   88           4  6b848725-e44d-42d8-a278-ae67faa9cb80  Female  10KM RUN
# 4   93           5  6b848725-e44d-42d8-a278-ae67faa9cb80  Female  10KM RUN
#
#           Nationality      Gun Time     Chip Time       Speed         Pace  \
# 0  [img:flags/SA.gif]  00:42:59.556  00:42:57.505  13.9 Km/Hr  4:17 min/km
# 1  [img:flags/CZ.gif]  00:43:28.175  00:43:24.774  13.8 Km/Hr  4:20 min/km
# 2  [img:flags/SA.gif]  00:44:00.251  00:43:56.317  13.6 Km/Hr  4:23 min/km
# 3  [img:flags/MA.gif]  00:48:28.115  00:48:22.908  12.4 Km/Hr  4:50 min/km
# 4  [img:flags/SA.gif]  00:58:37.753  00:48:27.714  12.3 Km/Hr  4:50 min/km
#
#   Distance
# 0    10 KM
# 1    10 KM
# 2    10 KM
# 3    10 KM
# ...

# %%
df.dtypes
# Out:
# Rank           object
# Gender Rank    object
# Name           object
# Gender         object
# Category       object
# Nationality    object
# Gun Time       object
# Chip Time      object
# Speed          object
# Pace           object
# Distance       object
# dtype: object

# %%
df['Rank'].unique()
# Out:
# array(['46', '53', '55', ..., '2278', '2279', '2280'], dtype=object)

# %%
df['Rank'] = df['Rank'].apply(lambda x: 0 if not x.isdigit() else x)

# %%
df['Rank'] = df['Rank'].astype('int64')

# %%
df["Gender Rank"] = df["Gender Rank"].apply(lambda x: 0 if not x.isdigit() else x)

# %%
df['Gender Rank'] = df['Gender Rank'].astype(int)

# %%
df.dtypes
# Out:
# Rank            int64
# Gender Rank     int64
# Name           object
# Gender         object
# Category       object
# Nationality    object
# Gun Time       object
# Chip Time      object
# Speed          object
# Pace           object
# Distance       object
# dtype: object

# %%
df.head()
# Out:
#    Rank  Gender Rank                                  Name  Gender  Category  \
# 0    46            1  6b848725-e44d-42d8-a278-ae67faa9cb80  Female  10KM RUN
# 1    53            2  6b848725-e44d-42d8-a278-ae67faa9cb80  Female  10KM RUN
# 2    55            3  6b848725-e44d-42d8-a278-ae67faa9cb80  Female  10KM RUN
# 3    88            4  6b848725-e44d-42d8-a278-ae67faa9cb80  Female  10KM RUN
# 4    93            5  6b848725-e44d-42d8-a278-ae67faa9cb80  Female  10KM RUN
#
#           Nationality      Gun Time     Chip Time       Speed         Pace  \
# 0  [img:flags/SA.gif]  00:42:59.556  00:42:57.505  13.9 Km/Hr  4:17 min/km
# 1  [img:flags/CZ.gif]  00:43:28.175  00:43:24.774  13.8 Km/Hr  4:20 min/km
# 2  [img:flags/SA.gif]  00:44:00.251  00:43:56.317  13.6 Km/Hr  4:23 min/km
# 3  [img:flags/MA.gif]  00:48:28.115  00:48:22.908  12.4 Km/Hr  4:50 min/km
# 4  [img:flags/SA.gif]  00:58:37.753  00:48:27.714  12.3 Km/Hr  4:50 min/km
#
#   Distance
# 0    10 KM
# 1    10 KM
# 2    10 KM
# ...

# %%
df2 = df.copy()

# %%
df.drop(columns=['Name'], inplace=True)

# %%
df.head()
# Out:
#    Rank  Gender Rank  Gender  Category         Nationality      Gun Time  \
# 0    46            1  Female  10KM RUN  [img:flags/SA.gif]  00:42:59.556
# 1    53            2  Female  10KM RUN  [img:flags/CZ.gif]  00:43:28.175
# 2    55            3  Female  10KM RUN  [img:flags/SA.gif]  00:44:00.251
# 3    88            4  Female  10KM RUN  [img:flags/MA.gif]  00:48:28.115
# 4    93            5  Female  10KM RUN  [img:flags/SA.gif]  00:58:37.753
#
#       Chip Time       Speed         Pace Distance
# 0  00:42:57.505  13.9 Km/Hr  4:17 min/km    10 KM
# 1  00:43:24.774  13.8 Km/Hr  4:20 min/km    10 KM
# 2  00:43:56.317  13.6 Km/Hr  4:23 min/km    10 KM
# 3  00:48:22.908  12.4 Km/Hr  4:50 min/km    10 KM
# 4  00:48:27.714  12.3 Km/Hr  4:50 min/km    10 KM

# %%
df['Category'].unique()
# Out:
# array(['10KM RUN', '4KM FUN RUN', 'HALF MARATHON', 'MARATHON',
#        'MARATHON ELITE', 'HALF MARATHON ELITE'], dtype=object)

# %%
df.dtypes
# Out:
# Rank            int64
# Gender Rank     int64
# Gender         object
# Category       object
# Nationality    object
# Gun Time       object
# Chip Time      object
# Speed          object
# Pace           object
# Distance       object
# dtype: object

# %%
df['Nationality'] = df['Nationality'].dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6397 entries, 0 to 6396
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         6397 non-null   int64
#  1   Gender Rank  6397 non-null   int64
#  2   Gender       6397 non-null   object
#  3   Category     6397 non-null   object
#  4   Nationality  6085 non-null   object
#  5   Gun Time     6397 non-null   object
#  6   Chip Time    6227 non-null   object
#  7   Speed        6227 non-null   object
#  8   Pace         6227 non-null   object
#  9   Distance     6397 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 499.9+ KB

# %%
df['Nationality'] = df['Nationality'].astype(str)
df['Nationality'] =  df['Nationality'].apply(lambda x: str(x)[len(x) -7:-5])

# %%
df.head()
# Out:
#    Rank  Gender Rank  Gender  Category Nationality      Gun Time  \
# 0    46            1  Female  10KM RUN          SA  00:42:59.556
# 1    53            2  Female  10KM RUN          CZ  00:43:28.175
# 2    55            3  Female  10KM RUN          SA  00:44:00.251
# 3    88            4  Female  10KM RUN          MA  00:48:28.115
# 4    93            5  Female  10KM RUN          SA  00:58:37.753
#
#       Chip Time       Speed         Pace Distance
# 0  00:42:57.505  13.9 Km/Hr  4:17 min/km    10 KM
# 1  00:43:24.774  13.8 Km/Hr  4:20 min/km    10 KM
# 2  00:43:56.317  13.6 Km/Hr  4:23 min/km    10 KM
# 3  00:48:22.908  12.4 Km/Hr  4:50 min/km    10 KM
# 4  00:48:27.714  12.3 Km/Hr  4:50 min/km    10 KM

# %%
# df['Gun Time'] = pd.to_datetime(df['Gun Time'], errors= "coerce")
# Out:
# /var/folders/h2/hjv5g_hx0cj2zdk5d0l8wvbm0000gn/T/ipykernel_71871/1896110612.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Gun Time'] = pd.to_datetime(df['Gun Time'], errors= "coerce")

# %%
# df['Chip Time'] = pd.to_datetime(df['Chip Time'], errors= "coerce")
# Out:
# /var/folders/h2/hjv5g_hx0cj2zdk5d0l8wvbm0000gn/T/ipykernel_71871/3350671886.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Chip Time'] = pd.to_datetime(df['Chip Time'], errors= "coerce")

# %%
df.rename(columns={'Speed': 'Speed Km/Hr'}, inplace=True)
df.head()
# Out:
#    Rank  Gender Rank  Gender  Category Nationality      Gun Time  \
# 0    46            1  Female  10KM RUN          SA  00:42:59.556
# 1    53            2  Female  10KM RUN          CZ  00:43:28.175
# 2    55            3  Female  10KM RUN          SA  00:44:00.251
# 3    88            4  Female  10KM RUN          MA  00:48:28.115
# 4    93            5  Female  10KM RUN          SA  00:58:37.753
#
#       Chip Time Speed Km/Hr         Pace Distance
# 0  00:42:57.505  13.9 Km/Hr  4:17 min/km    10 KM
# 1  00:43:24.774  13.8 Km/Hr  4:20 min/km    10 KM
# 2  00:43:56.317  13.6 Km/Hr  4:23 min/km    10 KM
# 3  00:48:22.908  12.4 Km/Hr  4:50 min/km    10 KM
# 4  00:48:27.714  12.3 Km/Hr  4:50 min/km    10 KM

# %%
df['Speed Km/Hr'].dropna(inplace=True)
df['Speed Km/Hr'] = df['Speed Km/Hr'].apply(lambda x: str(x).split()[0])

# %%
df.head()
# Out:
#    Rank  Gender Rank  Gender  Category Nationality      Gun Time  \
# 0    46            1  Female  10KM RUN          SA  00:42:59.556
# 1    53            2  Female  10KM RUN          CZ  00:43:28.175
# 2    55            3  Female  10KM RUN          SA  00:44:00.251
# 3    88            4  Female  10KM RUN          MA  00:48:28.115
# 4    93            5  Female  10KM RUN          SA  00:58:37.753
#
#       Chip Time Speed Km/Hr         Pace Distance
# 0  00:42:57.505        13.9  4:17 min/km    10 KM
# 1  00:43:24.774        13.8  4:20 min/km    10 KM
# 2  00:43:56.317        13.6  4:23 min/km    10 KM
# 3  00:48:22.908        12.4  4:50 min/km    10 KM
# 4  00:48:27.714        12.3  4:50 min/km    10 KM

# %%
df['Distance'].unique()
# Out:
# array(['10 KM', '5 KM', '0 KM', '4 KM', '21.1 KM', '20 KM', '15 KM',
#        '42.2 KM', '35 KM', '30 KM', '40 KM', '25 KM'], dtype=object)

# %%
df['Distance'].astype(str)
df.rename(columns={'Distance': 'Distance KM'}, inplace=True)

# %%
df['Distance KM'] = df['Distance KM'].apply(lambda x: str(x).split()[0])

# %%
df.head()
# Out:
#    Rank  Gender Rank  Gender  Category Nationality      Gun Time  \
# 0    46            1  Female  10KM RUN          SA  00:42:59.556
# 1    53            2  Female  10KM RUN          CZ  00:43:28.175
# 2    55            3  Female  10KM RUN          SA  00:44:00.251
# 3    88            4  Female  10KM RUN          MA  00:48:28.115
# 4    93            5  Female  10KM RUN          SA  00:58:37.753
#
#       Chip Time Speed Km/Hr         Pace Distance KM
# 0  00:42:57.505        13.9  4:17 min/km          10
# 1  00:43:24.774        13.8  4:20 min/km          10
# 2  00:43:56.317        13.6  4:23 min/km          10
# 3  00:48:22.908        12.4  4:50 min/km          10
# 4  00:48:27.714        12.3  4:50 min/km          10

# %%
df.dtypes
# Out:
# Rank            int64
# Gender Rank     int64
# Gender         object
# Category       object
# Nationality    object
# Gun Time       object
# Chip Time      object
# Speed Km/Hr    object
# Pace           object
# Distance KM    object
# dtype: object

# %%
df['Distance KM'] = df['Distance KM'].astype(float)
df['Speed Km/Hr'] = df['Speed Km/Hr'].astype(float)

# %%
df.dtypes
# Out:
# Rank             int64
# Gender Rank      int64
# Gender          object
# Category        object
# Nationality     object
# Gun Time        object
# Chip Time       object
# Speed Km/Hr    float64
# Pace            object
# Distance KM    float64
# dtype: object

# %%
df.head()
# Out:
#    Rank  Gender Rank  Gender  Category Nationality      Gun Time  \
# 0    46            1  Female  10KM RUN          SA  00:42:59.556
# 1    53            2  Female  10KM RUN          CZ  00:43:28.175
# 2    55            3  Female  10KM RUN          SA  00:44:00.251
# 3    88            4  Female  10KM RUN          MA  00:48:28.115
# 4    93            5  Female  10KM RUN          SA  00:58:37.753
#
#       Chip Time  Speed Km/Hr         Pace  Distance KM
# 0  00:42:57.505         13.9  4:17 min/km         10.0
# 1  00:43:24.774         13.8  4:20 min/km         10.0
# 2  00:43:56.317         13.6  4:23 min/km         10.0
# 3  00:48:22.908         12.4  4:50 min/km         10.0
# 4  00:48:27.714         12.3  4:50 min/km         10.0

# %%
df['Pace'] = df['Pace'].apply(lambda x: str(x).split()[0])
df.rename(columns={'Pace': 'Pace min/km'}, inplace=True)

# %%
df.head()
# Out:
#    Rank  Gender Rank  Gender  Category Nationality      Gun Time  \
# 0    46            1  Female  10KM RUN          SA  00:42:59.556
# 1    53            2  Female  10KM RUN          CZ  00:43:28.175
# 2    55            3  Female  10KM RUN          SA  00:44:00.251
# 3    88            4  Female  10KM RUN          MA  00:48:28.115
# 4    93            5  Female  10KM RUN          SA  00:58:37.753
#
#       Chip Time  Speed Km/Hr Pace min/km  Distance KM
# 0  00:42:57.505         13.9        4:17         10.0
# 1  00:43:24.774         13.8        4:20         10.0
# 2  00:43:56.317         13.6        4:23         10.0
# 3  00:48:22.908         12.4        4:50         10.0
# 4  00:48:27.714         12.3        4:50         10.0

# %%
df[df["Gender"]=='Female']["Category"].value_counts()
# Out:
# Category
# 4KM FUN RUN            1069
# 10KM RUN                795
# HALF MARATHON           233
# MARATHON                 75
# MARATHON ELITE            9
# HALF MARATHON ELITE       3
# Name: count, dtype: int64

# %%
df[df["Gender"]=='Male']["Speed Km/Hr"].value_counts()
# Out:
# Speed Km/Hr
# 8.5     85
# 8.7     77
# 8.8     76
# 7.3     74
# 8.9     74
#         ..
# 14.8     1
# 2.8      1
# 2.6      1
# 2.2      1
# 19.2     1
# Name: count, Length: 178, dtype: int64

# %%
# #who run fast (female or male ) take the average of speed

avg_speed_by_gender = df.groupby('Gender')['Speed Km/Hr'].mean()
print(avg_speed_by_gender)
print(avg_speed_by_gender.plot.pie())
# Out:
# Gender
# Female    6.511315
# Male      8.484525
# Name: Speed Km/Hr, dtype: float64
# Axes(0.22375,0.11;0.5775x0.77)

# %%
#who can stay for long time   (female or male ) country
longest_time= df.groupby(['Gender', 'Nationality' , ])['Distance KM'].max()
print(longest_time)
# Out:
# Gender  Nationality
# Female                 42.2
#         AE             21.1
#         AF              4.0
#         AM              4.0
#         AT             21.1
#                        ...
# Male    UA             42.2
#         UG             21.1
#         VE             21.1
#         YE             42.2
#         ZA             42.2
# Name: Distance KM, Length: 150, dtype: float64

# %%
#the 10 fastest country
fastest_countries = df.groupby('Nationality')['Speed Km/Hr'].mean().nlargest(5)
print(fastest_countries)
# Out:
# Nationality
# ET    15.258824
# KE    15.243478
# UG    13.450000
# QA    12.614286
# KW    12.566667
# Name: Speed Km/Hr, dtype: float64
